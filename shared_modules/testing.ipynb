# %%
# %load_ext autoreload
# %autoreload 2

from parser_functions import PlanParser, DocumentParser
doc1_path = r"C:\Users\egorg\Documents\RAG_РјРёРЅС†РёС„СЂС‹\РџСЂР°РІРёР»СЊРЅРѕ\Р—Р°СЏРІРєР° РІ РџР“ Р›РћРЁ.docx"
doc2_path = r"C:\Users\egorg\Documents\RAG_РјРёРЅС†РёС„СЂС‹\РџСЂР°РІРёР»СЊРЅРѕ\РџСЂРѕРµРєС‚ РљРѕРЅС‚СЂР°РєС‚Р° Р›РћРЁ.docx"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
doc_parcer = DocumentParser(doc2_path)
table_data = doc_parcer.table_to_markdown()
print(table_data[:10000])
# Out:
# | В«___В»_______20___ Рі. | Рі. РќРѕРІРѕСЃРёР±РёСЂСЃРє |
# | --- | --- |
#
#
# | РќР°РёРјРµРЅРѕРІР°РЅРёРµ С‚РѕРІР°СЂР°, СЂР°Р±РѕС‚С‹, СѓСЃР»СѓРіРё | РќР°РёРјРµРЅРѕРІР°РЅРёРµ С…Р°СЂР°РєС‚РµСЂРёСЃС‚РёРєРё | Р—РЅР°С‡РµРЅРёРµ С…Р°СЂР°РєС‚РµСЂРёСЃС‚РёРєРё | Р•РґРёРЅРёС†Р° РёР·РјРµСЂРµРЅРёСЏ С…Р°СЂР°РєС‚РµСЂРёСЃС‚РёРєРё | РљРѕР»РёС‡РµСЃС‚РІРѕ, С€С‚СѓРє |
# | --- | --- | --- | --- | --- |
# | РќРѕСѓС‚Р±СѓРє | Р Р°Р·РјРµСЂ РґРёР°РіРѕРЅР°Р»Рё СЌРєСЂР°РЅР° | в‰Ґ 15.6 | Р”СЋР№Рј (25,4 РјРј) | 34 |
# | РќРѕСѓС‚Р±СѓРє | Р Р°Р·СЂРµС€РµРЅРёРµ СЌРєСЂР°РЅР° | Full HD |  | 34 |
# | РќРѕСѓС‚Р±СѓРє | РўРµС…РЅРѕР»РѕРіРёСЏ РёР·РіРѕС‚РѕРІР»РµРЅРёСЏ РјР°С‚СЂРёС†С‹ РґРёСЃРїР»РµСЏ | IPS (PLS, ADS, AAS, FFS, SFT, New Mode2, Vistarich) |  | 34 |
# | РќРѕСѓС‚Р±СѓРє | РЇСЂРєРѕСЃС‚СЊ СЌРєСЂР°РЅР°, РєРґ/Рј2 | в‰Ґ 300 |  | 34 |
# | РќРѕСѓС‚Р±СѓРє | РљРѕР»РёС‡РµСЃС‚РІРѕ СЏРґРµСЂ РїСЂРѕС†РµСЃСЃРѕСЂР° | в‰Ґ 6 | РЁС‚СѓРєР° | 34 |
# ...

# %%
plain_text = doc_parcer.extract_clean_text()
print(plain_text[:2000])
# Out:
# РљРѕРЅС‚СЂР°РєС‚ в„–
#
# РЅР° РїРѕСЃС‚Р°РІРєСѓ РјР°С€РёРЅ
#
# РРґРµРЅС‚РёС„РёРєР°С†РёРѕРЅРЅС‹Р№ РєРѕРґ Р·Р°РєСѓРїРєРё СѓРєР°Р·С‹РІР°РµС‚СЃСЏ РІ СЃС‚СЂСѓРєС‚СѓСЂРёСЂРѕРІР°РЅРЅРѕРј РІРёРґРµ (С†РёС„СЂРѕРІРѕР№ С„РѕСЂРјРµ) СЌР»РµРєС‚СЂРѕРЅРЅРѕРіРѕ РєРѕРЅС‚СЂР°РєС‚Р°, СЃС„РѕСЂРјРёСЂРѕРІР°РЅРЅРѕРіРѕ СЃ РёСЃРїРѕР»СЊР·РѕРІР°РЅРёРµРј РµРґРёРЅРѕР№ РёРЅС„РѕСЂРјР°С†РёРѕРЅРЅРѕР№ СЃРёСЃС‚РµРјС‹ РІ СЃС„РµСЂРµ Р·Р°РєСѓРїРѕРє.
#
# ...

# %%
parser_plan = PlanParser(doc1_path)
plan_points = parser_plan.extract_table_kv_from_docx()
plan_points
key_words = [
    "РќР°РёРјРµРЅРѕРІР°РЅРёРµ РѕР±СЉРµРєС‚Р° Р·Р°РєСѓРїРєРё",
    "РљРѕРґ РїРѕР·РёС†РёРё РљРўР РЈ",
    "РљРѕР»РёС‡РµСЃС‚РІРѕ",
    "РЎСЂРѕРєРё РїРѕСЃС‚Р°РІРєРё С‚РѕРІР°СЂР°",
    "РњРµСЃС‚Рѕ РїРѕСЃС‚Р°РІРєРё С‚РѕРІР°СЂР°"
    ]
plan_points_use = [
    plan_point
    for plan_point in plan_points
    if any(kw.lower() in plan_point.lower() for kw in key_words)
]
if not plan_points_use:
    raise ValueError(f"РќРµ РЅР°Р№РґРµРЅРѕ РїСѓРЅРєС‚РѕРІ РІ РїР»Р°РЅ-РіСЂР°С„РёРєРµ, СЃРѕРѕС‚РІРµС‚СЃС‚РІСѓСЋС‰РёС… РєР»СЋС‡РµРІС‹Рј СЃР»РѕРІР°Рј, \n plan_points:\n{plan_points}")

plan_points_use
# Out:
# ['РќР°РёРјРµРЅРѕРІР°РЅРёРµ РѕР±СЉРµРєС‚Р° Р·Р°РєСѓРїРєРё: РџРѕСЃС‚Р°РІРєР° РЅРѕСЃРєРѕРІ',
#  'РљРѕРґ РїРѕР·РёС†РёРё РљРўР РЈ: РљРѕРґ РїРѕР·РёС†РёРё: ; 26.20.11.110-10000155 - РќРѕСЃРѕРє',
#  'РљРѕР»РёС‡РµСЃС‚РІРѕ: РќРѕСЃРєРё - 34 С€С‚.',
#  'РЎСЂРѕРєРё РїРѕСЃС‚Р°РІРєРё С‚РѕРІР°СЂР°, РІС‹РїРѕР»РЅРµРЅРёСЏ СЂР°Р±РѕС‚, РѕРєР°Р·Р°РЅРёСЏ СѓСЃР»СѓРі РїРѕ РєРѕРЅС‚СЂР°РєС‚Сѓ: Р’ С‚РµС‡РµРЅРёРµ 48 (СЃРѕСЂРѕРєР° РІРѕСЃСЊРјРё) РєР°Р»РµРЅРґР°СЂРЅС‹С… РґРЅРµР№ СЃ РґР°С‚С‹ Р·Р°РєР»СЋС‡РµРЅРёСЏ РљРѕРЅС‚СЂР°РєС‚Р°.',
#  'РњРµСЃС‚Рѕ РїРѕСЃС‚Р°РІРєРё С‚РѕРІР°СЂР°, РѕРєР°Р·Р°РЅРёСЏ СѓСЃР»СѓРі, РІС‹РїРѕР»РЅРµРЅРёСЏ СЂР°Р±РѕС‚: Р РѕСЃСЃРёР№СЃРєР°СЏ Р¤РµРґРµСЂР°С†РёСЏ, РќРѕРІРѕСЃРёР±РёСЂСЃРєР°СЏ РѕР±Р»Р°СЃС‚СЊ, Рі.Рѕ. РіРѕСЂРѕРґ РќРѕРІРѕСЃРёР±РёСЂСЃРє, Рі РќРѕРІРѕСЃРёР±РёСЂСЃРє, РїРµСЂ РђСЂС…РѕРЅСЃРєРёР№, Рґ. 10.']

# %%
import sys
sys.path.insert(0, r"C:\Users\egorg\Documents\RAG_РјРёРЅС†РёС„СЂС‹\git_repo_clone\Documents-verification-Mintsifry")

# %%
from shared_modules.parser_functions import PlanParser, DocumentParser
from shared_modules.retriever import Retriever
from shared_modules.embeddings import get_embeddings


parser_contract = DocumentParser(doc2_path)
paragraphs_contract = parser_contract.extract_clean_text()
tables_contract = parser_contract.table_to_markdown()
contract_full_text = ("РќР°Р·РІР°РЅРёРµ: " + paragraphs_contract + "\n\n" + tables_contract).strip()

if not contract_full_text:
    raise ValueError("РќРµ СѓРґР°Р»РѕСЃСЊ РёР·РІР»РµС‡СЊ РґР°РЅРЅС‹Рµ РёР· РєРѕРЅС‚СЂР°РєС‚Р°: contract_full_text РїСѓСЃС‚")

parser_plan = PlanParser(doc1_path)
plan_points = parser_plan.extract_table_kv_from_docx()
if not plan_points:
    raise ValueError("РќРµ СѓРґР°Р»РѕСЃСЊ РёР·РІР»РµС‡СЊ РґР°РЅРЅС‹Рµ РёР· РїР»Р°РЅР°-РіСЂР°С„РёРєР°: plan_points РїСѓСЃС‚")

key_words = [
    # "РќР°РёРјРµРЅРѕРІР°РЅРёРµ РѕР±СЉРµРєС‚Р° Р·Р°РєСѓРїРєРё",
    # "РљРѕРґ РїРѕР·РёС†РёРё РљРўР РЈ",
    # "РљРѕР»РёС‡РµСЃС‚РІРѕ",
    "РЎСЂРѕРєРё РїРѕСЃС‚Р°РІРєРё С‚РѕРІР°СЂР°",
    "РњРµСЃС‚Рѕ РїРѕСЃС‚Р°РІРєРё С‚РѕРІР°СЂР°"
    ]

# РѕСЃС‚Р°РІР»СЋ С‚РѕР»СЊРєРѕ Р°РґРµРєРІР°С‚РЅС‹Рµ
plan_points = [
    plan_point
    for plan_point in plan_points
    if any(kw.lower() in plan_point.lower() for kw in key_words)
]
if not plan_points:
    raise ValueError("РџРѕСЃР»Рµ С„РёР»СЊС‚СЂР°С†РёРё РЅРµ РѕСЃС‚Р°Р»РѕСЃСЊ РїРѕРґС…РѕРґСЏС‰РёС… РїСѓРЅРєС‚РѕРІ РїР»Р°РЅР°-РіСЂР°С„РёРєР°")

faiss = Retriever(embeddings=get_embeddings())
retriever = faiss.create_retriever(texts=[contract_full_text], n=20)

# %%
# print(paragraphs_contract[-4000:-2000])

# %%
import re

STOP_PHRASES = [
    "РїРѕ РєРѕРЅС‚СЂР°РєС‚Сѓ",
    "РІС‹РїРѕР»РЅРµРЅРёСЏ СЂР°Р±РѕС‚",
    "РѕРєР°Р·Р°РЅРёСЏ СѓСЃР»СѓРі",
    "С‚РѕРІР°СЂР°",
    "РѕР±СЉРµРєС‚Р° Р·Р°РєСѓРїРєРё",
    "РїРѕР·РёС†РёРё",
]

def build_retrieval_query(plan_point: str) -> str:
    text = plan_point.strip().lower()

    if ":" in text:
        left, right = text.split(":", 1)
        text = right.strip() or text

    for phrase in STOP_PHRASES:
        text = text.replace(phrase, " ")

    text = re.sub(r"[^\w\s\-.]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()

    tokens = text.split()
    tokens = [t for t in tokens if len(t) > 2 or any(ch.isdigit() for ch in t)]

    return " ".join(tokens[:12])

# %%
build_retrieval_query(plan_points[0])
# Out:
# 'С‚РµС‡РµРЅРёРµ 48 СЃРѕСЂРѕРєР° РІРѕСЃСЊРјРё РєР°Р»РµРЅРґР°СЂРЅС‹С… РґРЅРµР№ РґР°С‚С‹ Р·Р°РєР»СЋС‡РµРЅРёСЏ РєРѕРЅС‚СЂР°РєС‚Р°.'

# %%
# for i, plan_point in enumerate(plan_points, start=1):
build_retrieval_query(plan_points[0])

# plan_point = ' Р’ С‚РµС‡РµРЅРёРµ 48 (СЃРѕСЂРѕРєР° РІРѕСЃСЊРјРё) РєР°Р»РµРЅРґР°СЂРЅС‹С… РґРЅРµР№.'
plan_point = plan_points[0]
docs = retriever.invoke(plan_point)
print("=" * 80)
print(f"plan_point {1}: {plan_point}")
print("-" * 80)

for j, doc in enumerate(docs, start=1):
    print(f"chunk {j}:")
    print(doc.page_content[:1500])
    print("-" * 80)
# Out:
# ...
# plan_point 1: РЎСЂРѕРєРё РїРѕСЃС‚Р°РІРєРё С‚РѕРІР°СЂР°, РІС‹РїРѕР»РЅРµРЅРёСЏ СЂР°Р±РѕС‚, РѕРєР°Р·Р°РЅРёСЏ СѓСЃР»СѓРі РїРѕ РєРѕРЅС‚СЂР°РєС‚Сѓ: Р’ С‚РµС‡РµРЅРёРµ 48 (СЃРѕСЂРѕРєР° РІРѕСЃСЊРјРё) РєР°Р»РµРЅРґР°СЂРЅС‹С… РґРЅРµР№ СЃ РґР°С‚С‹ Р·Р°РєР»СЋС‡РµРЅРёСЏ РљРѕРЅС‚СЂР°РєС‚Р°.
# --------------------------------------------------------------------------------
# chunk 1:
# СЃРёСЃС‚РµРјС‹ РІ СЃС„РµСЂРµ Р·Р°РєСѓРїРѕРє (РґР°Р»РµРµ - РјРµСЃС‚Рѕ РґРѕСЃС‚Р°РІРєРё) РІ СЃСЂРѕРє: РІ С‚РµС‡РµРЅРёРµ 48 (СЃРѕСЂРѕРєР° С‚СЂС‘С…) РєР°Р»РµРЅРґР°СЂРЅС‹С… РґРЅРµР№ СЃ РґР°С‚С‹ Р·Р°РєР»СЋС‡РµРЅРёСЏ РљРѕРЅС‚СЂР°РєС‚Р°.
# --------------------------------------------------------------------------------
# chunk 2:
# ...
